# %%
f = open('assets/spam.txt', mode='r')
print(f.read())
f.close()
print(f.closed) #boolean
# Out:
# spam in here
# but also some eggs
# False

# %%
with open('assets/spam.txt', mode='r') as f : 
    res = f.read()
    print(1,f.closed)
    
print(res)  
print(2, f.closed)
# Out:
# 1 False
# spam in here
# but also some eggs
# 2 True

# %%
with open('assets/spam.txt', mode='w') as f : 
    f.write("nothing but potato !!")

# %%
with open('assets/spam.txt', mode='a') as f : 
    f.write("second potato is here!!")

# %%
with open('assets/brain.jpeg', 'r') as image :
   res= image.read()
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x13\x13\x12\x15\x13\x13\x13\x16\x15\x15\x17\x18\x17\x18\x18\x18\x18\x19\x17\x1a\x1a\x1b\x17\x15\x17\x17\x17\x17\x1a\x1a\x17\x18\x1d( \x18\x1a%\x1d\x17\x15!1!%)+...\x17\x1f383-7(-.+\x01\n\n\n\x0e\r\x0e\x1b\x10\x10\x1b/& &----/5--------------------------------------------\xff\xc0\x00\x11\x08\x00\xc2\x01\x03\x03\x01\x11\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x02\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x04\x02\x05\x06\x01\x00\x07\x08\xff\xc4\x00E\x10\x00\x02\x01\x02\x03\x04\x08\x02\x07\x06\x04\x05\x05\x01\x00\x00\x01\x02\x11\x00\x03\x04\x12!\x051AQ\x06\x13"aq\x81\x91\xa12\xb1\x14BRb\x92\xc1\xd1#r\x82\xa2\xe1\xf0\x07\x15\xc2\xf1Ss\x93\xb2\xd2\x163Cc\x83$\xff\xc4\x00\x1a\x01\x00\x02\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x00\x01\x04\x05\x06\xff\xc4\x00=\x11\x00\x01\x04\x00\x04\x02\x08\x05\x03\x03\x02\x05\x05\x00\x00\x00\x01\x00\x02\x
# ...

# %%
print(dir(f))
print(help(f.truncate))
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']
# Help on built-in function truncate:
#
# truncate(pos=None, /) method of _io.TextIOWrapper instance
#     Truncate file to size bytes.
#
#     File pointer is left unchanged.  Size defaults to the current IO
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(help(f.truncate()))
#
# ValueError: I/O operation on closed file.

# %%
x=[1,2,3]
print(dir(x))
print(help(x.__format__))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
# Help on built-in function __format__:
#
# __format__(format_spec, /) method of builtins.list instance
#     Default object formatter.
#
# None

# %%
with open("assets/ibrahim.txt",'w') as f:
    f.read()
